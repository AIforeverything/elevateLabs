# %% [markdown]
# ## Loading required libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## loading data in .csv to a dataframe using pandas

# %%
df=pd.read_csv("Superstore.csv",encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ## Finding null values/ missing values

# %%
df.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ## no null values were found

# %%
df.Country
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 9989    United States
# 9990    United States
# 9991    United States
# 9992    United States
# 9993    United States
# Name: Country, Length: 9994, dtype: object

# %%
df.City.value_counts()
# Out:
# City
# New York City      915
# Los Angeles        747
# Philadelphia       537
# San Francisco      510
# Seattle            428
#                   ...
# Glenview             1
# Missouri City        1
# Rochester Hills      1
# Palatine             1
# Manhattan            1
# Name: count, Length: 531, dtype: int64

# %% [markdown]
# ## finding maximum sales for a region

# %%
df.Region.groupby(df["Sales"]).sum().value_counts()
# Out:
# Region
# West                                                       1125
# East                                                       1119
# Central                                                     960
# South                                                       635
# WestWest                                                    174
#                                                            ...
# CentralEastEastCentralWestEastSouthSouthEast                  1
# WestEastSouthCentralWestWest                                  1
# EastWestWestEastCentralWest                                   1
# WestCentralSouthWestWestWestCentralEastWestEastWestEast       1
# CentralWestEastWest                                           1
# Name: count, Length: 454, dtype: int64

# %% [markdown]
# ## West region has highest sales of 1125 and east region has the second highest sales of 1119.

# %%
df.City.groupby(df.Sales).sum().value_counts()
# Out:
# City
# New York City                                                                         330
# Philadelphia                                                                          245
# Los Angeles                                                                           232
# San Francisco                                                                         164
# Houston                                                                               153
#                                                                                      ...
# WilmingtonArlington                                                                     1
# South BendRochesterSan FranciscoMoreno ValleyRichmondBaltimoreSan FranciscoDetroit      1
# YonkersMinneapolisNew York City                                                         1
# GreshamSeattle                                                                          1
# ...

# %% [markdown]
# ## New York City has highest sales of 330 and Philadelphia  has the second highest sales of 245.

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.corr(numeric_only=True).plot()
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
df.plot(x="Postal Code", y="Profit", kind="scatter")
# Out:
# <Axes: xlabel='Postal Code', ylabel='Profit'>

# %%
df["Postal Code"].groupby(df.Profit).sum().value_counts()
# Out:
# Postal Code
# 10024     131
# 10035     129
# 10009     125
# 10011     113
# 19134     108
#          ...
# 150271      1
# 553668      1
# 98737       1
# 225818      1
# 144463      1
# Name: count, Length: 2071, dtype: int64

# %% [markdown]
# ## Postal code 10024 has highest profit of 131 and 10035 has the second highest 129.
